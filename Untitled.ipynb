# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from fastai.imports import *
from fastai.structured import *

from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display

from sklearn import metrics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-713ddf51e021> in <module>()
# ----> 1 from fastai.imports import *
#       2 from fastai.structured import *
#       3
#       4 from pandas_summary import DataFrameSummary
#       5 from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
#
# ModuleNotFoundError: No module named 'fastai'

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# '/Users/shuosun/Google Drive (petersun)/Titanic'

# %%
import pandas as pd

# %%
data = pd.read_csv('data.combined.csv')

# %%
data
# Out:
#      Survived  PassengerId  Pclass  \
# 0           0            1       3
# 1           1            2       1
# 2           1            3       3
# 3           1            4       1
# 4           0            5       3
# 5           0            6       3
# 6           0            7       1
# 7           0            8       3
# 8           1            9       3
# 9           1           10       2
# 10          1           11       3
# 11          1           12       1
# 12          0           13       3
# 13          0           14       3
# 14          0           15       3
# 15          1           16       2
# 16          0           17       3
# 17          1           18       2
# 18          0           19       3
# 19          1           20       3
# 20          0           21       2
# 21          1           22       2
# 22          1           23       3
# 23          1           24       1
# 24          0           25       3
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestClassifier

# %%
train_X = data.loc[1:891, ["Pclass", "new.title","family.size","avg.fare"]]
# df.loc[:, ['foo','bar','dat']]
train_X
# Out:
#      Pclass new.title  family.size   avg.fare
# 1         1      Mrs.            2  35.641650
# 2         3     Miss.            1   7.925000
# 3         1      Mrs.            2  26.550000
# 4         3       Mr.            1   8.050000
# 5         3       Mr.            1   8.458300
# 6         1       Mr.            1  25.931250
# 7         3   Master.            5   4.215000
# 8         3      Mrs.            3   3.711100
# 9         2      Mrs.            2  15.035400
# 10        3     Miss.            3   5.566667
# 11        1     Miss.            1  26.550000
# 12        3       Mr.            1   8.050000
# 13        3       Mr.            7   4.467857
# 14        3     Miss.            1   7.854200
# 15        2      Mrs.            1  16.000000
# 16        3   Master.            6   4.854167
# 17        2       Mr.            1  13.000000
# 18        3      Mrs.            2   9.000000
# 19        3      Mrs.            1   7.225000
# ...

# %%
train_y=data.loc[1:891, ["Survived"]]
train_y
# Out:
#     Survived
# 1          1
# 2          1
# 3          1
# 4          0
# 5          0
# 6          0
# 7          0
# 8          1
# 9          1
# 10         1
# 11         1
# 12         0
# 13         0
# 14         0
# 15         1
# 16         0
# 17         1
# 18         0
# 19         1
# 20         0
# 21         1
# 22         1
# 23         1
# 24         0
# 25         1
# 26         0
# 27         0
# 28         1
# 29         0
# 30         0
# ..       ...
# 862        1
# 863        0
# 864        0
# 865        1
# 866        1
# 867        0
# 868        0
# 869        1
# 870        0
# 871        1
# 872        0
# 873        0
# 874        1
# 875        1
# 876        0
# 877        0
# 878        0
# 879        1
# 880        1
# 881        0
# 882        0
# 883        0
# 884        0
# 885        0
# 886        0
# 887        1
# 888        0
# 889        1
# 890        0
# 891     None
#
# [891 rows x 1 columns]

# %%
# train_y=train_y.values

# %%
train_y
# Out:
#     Survived
# 1          1
# 2          1
# 3          1
# 4          0
# 5          0
# 6          0
# 7          0
# 8          1
# 9          1
# 10         1
# 11         1
# 12         0
# 13         0
# 14         0
# 15         1
# 16         0
# 17         1
# 18         0
# 19         1
# 20         0
# 21         1
# 22         1
# 23         1
# 24         0
# 25         1
# 26         0
# 27         0
# 28         1
# 29         0
# 30         0
# ..       ...
# 862        1
# 863        0
# 864        0
# 865        1
# 866        1
# 867        0
# 868        0
# 869        1
# 870        0
# 871        1
# 872        0
# 873        0
# 874        1
# 875        1
# 876        0
# 877        0
# 878        0
# 879        1
# 880        1
# 881        0
# 882        0
# 883        0
# 884        0
# 885        0
# 886        0
# 887        1
# 888        0
# 889        1
# 890        0
# 891     None
#
# [891 rows x 1 columns]

# %%
preds_X=data.loc[892:1309, ["Pclass", "new.title","family.size","avg.fare"]]

# %%
preds_X
# Out:
#       Pclass  family.size   avg.fare  new.title_Master.  new.title_Miss.  \
# 892        3            2   7.000000                  0                0
# 893        2            1   9.687500                  0                0
# 894        3            1   8.662500                  0                0
# 895        3            3   6.143750                  0                0
# 896        3            1   9.225000                  0                0
# 897        3            1   7.629200                  0                1
# 898        2            3   9.666667                  0                0
# 899        3            1   7.229200                  0                0
# 900        3            3   8.050000                  0                0
# 901        3            1   7.895800                  0                0
# 902        1            1  26.000000                  0                0
# 903        1            2  41.133350                  0                0
# ...

# %%
train_X=pd.get_dummies(train_X)
preds_X=pd.get_dummies(preds_X)
data.loc[1043]
# train_X
# Out:
# Survived                           None
# PassengerId                        1044
# Pclass                                3
# Name                 Storey, Mr. Thomas
# Sex                                male
# Age                                60.5
# SibSp                                 0
# Parch                                 0
# Ticket                             3701
# Fare                                NaN
# Cabin                               NaN
# Embarked                              S
# survived                           None
# pclass                                3
# title                               Mr.
# family.size                           1
# last.name                        Storey
# new.title                           Mr.
# ticket.party.size                     1
# avg.fare                            7.8
# Name: 1043, dtype: object

# %%
forest_model = RandomForestClassifier(random_state=1)

forest_model.fit(train_X, train_y)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
preds_Y = forest_model.predict(preds_X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-768eb7a5d298> in <module>()
#       1 preds_Y = forest_model.predict(preds_X)
# ----> 2 preds_Y.to_csv('rf_sub_python.csv', sep=",", index = False)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'

# %%
predictions = pd.DataFrame(preds_Y, columns=['Survived'])
predictions
# Out:
#     Survived
# 0          1
# 1          0
# 2          0
# 3          1
# 4          0
# 5          0
# 6          0
# 7          1
# 8          0
# 9          0
# 10         0
# 11         1
# 12         0
# 13         1
# 14         1
# 15         0
# 16         0
# 17         0
# 18         1
# 19         0
# 20         1
# 21         1
# 22         0
# 23         1
# 24         0
# 25         1
# 26         0
# 27         1
# 28         0
# 29         0
# ..       ...
# 387        0
# 388        0
# 389        0
# 390        1
# 391        1
# 392        0
# 393        0
# 394        1
# 395        0
# 396        1
# 397        0
# 398        0
# 399        1
# 400        0
# 401        1
# 402        0
# 403        0
# 404        0
# 405        0
# 406        0
# 407        1
# 408        0
# 409        1
# 410        1
# 411        0
# 412        0
# 413        1
# 414        0
# 415        0
# 416        1
#
# [417 rows x 1 columns]

# %%
predictions.to_csv('rf_sub_python.csv', sep=",", index = False)

# %%
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-41cb758eece3> in <module>()
# ----> 1 forest_model.fit(train_X, train_y)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     274
#     275         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
# --> 276             y = np.ascontiguousarray(y, dtype=DOUBLE)
#     277
#     278         if expanded_class_weight is not None:
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in ascontiguousarray(a, dtype)
#     579
#     580     """
# ...
